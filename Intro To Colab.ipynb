# %%
#!pip list
import torch
# Out:
# Package                   Version
# ------------------------- --------------
# anyio                     4.6.2.post1
# apparmor                  3.1.7
# appdirs                   1.4.4
# argcomplete               3.5.1
# argon2-cffi               23.1.0
# argon2-cffi-bindings      21.2.0
# arrow                     1.3.0
# asttokens                 2.4.1
# async-lru                 2.0.4
# attrs                     24.2.0
# babel                     2.16.0
# Beaker                    1.12.1
# beautifulsoup4            4.12.3
# bleach                    6.2.0
# boto3                     1.35.46
# botocore                  1.35.46
# Brlapi                    0.8.5
# Brotli                    1.1.0
# cairocffi                 1.6.1
# CairoSVG                  2.7.0
# certifi                   2023.5.7
# cffi                      1.16.0
# charset-normalizer        3.3.2
# click                     8.1.7
# click-plugins             1.1.1
# comm                      0.2.2
# ...
